# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.manifold import TSNE
from sklearn import preprocessing
from util.util_data import *

np.set_printoptions(suppress=True)

# %%
def save_obj_curr_folder(obj, name):
    with open(name, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj_curr_folder(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
pl_X_dict = load_json_to_dict('data_pl_dzrmeta/pl_X_dict.json')
pl_Y_title_dict = load_json_to_dict('data_pl_dzrmeta/pl_Y_title_dict.json')

pl_X_list = load_txt_to_list('data_pl_dzrmeta/pl_X_list.txt')
pl_key_to_id_dict = load_json_to_dict('data_pl_dzrmeta/pl_key_to_id_dict.json')

# pl_X = load_obj_curr_folder('data_pl_dzrmeta/pl_X.p')
# pl_Y_desc = load_obj_curr_folder('data_pl_dzrmeta/pl_Y_desc.p')
# pl_Y_title = load_obj_curr_folder('data_pl_dzrmeta/pl_Y_title.p')

# %%
pl_X = []
for _item in pl_X_list:
    pl_X.append(eval(_item))

# %%
pl_X = np.array(pl_X)

# %%
pl_X.shape
# Out:
# (137247, 404)

# %%
std_pl_X = preprocessing.scale(pl_X, axis=0)

# %%
A = std_pl_X
interia_ls = []
for k in range (1, 10):
    # Create a kmeans model on our data, using k clusters.  random_state helps ensure that the algorithm returns the same results each time.
    kmeans_model = KMeans(n_clusters=k, random_state=1).fit(A)

    # These are our fitted labels for clusters -- the first cluster has label 0, and the second has label 1.
    labels = kmeans_model.labels_

    # Sum of distances of samples to their closest cluster center
    interia = kmeans_model.inertia_
    interia_ls.append(interia)
    print("k:",k, " distance to closest centroid:", interia)
# Out:
# k: 1  distance to closest centroid: 19351827.000000738
# k: 2  distance to closest centroid: 17752295.27159977
# k: 3  distance to closest centroid: 16654055.952327007
# k: 4  distance to closest centroid: 15851734.791457564
# k: 5  distance to closest centroid: 15216244.511560608
# k: 6  distance to closest centroid: 14741762.81718254
# k: 7  distance to closest centroid: 14260084.655223215
# k: 8  distance to closest centroid: 13996587.055190986
# k: 9  distance to closest centroid: 13707831.612904811

# %%
plt.figure(figsize=(5,5))
plt.scatter(range(1, 10), interia_ls);
plt.plot(range(1, 10), interia_ls);

# %% [markdown]
# ## Only count vector features

# %%
pl_X_ent = pl_X[:, :-16]

std_pl_X_ent = preprocessing.scale(pl_X_ent, axis=0)

# %%
std_pl_X_ent.shape
# Out:
# (137247, 388)

# %%
# A = std_pl_X_ent
A = pl_X_ent
interia_ls = []
for k in range (1, 10):
    # Create a kmeans model on our data, using k clusters.  random_state helps ensure that the algorithm returns the same results each time.
    kmeans_model = KMeans(n_clusters=k, random_state=1).fit(A)

    # These are our fitted labels for clusters -- the first cluster has label 0, and the second has label 1.
    labels = kmeans_model.labels_

    # Sum of distances of samples to their closest cluster center
    interia = kmeans_model.inertia_
    interia_ls.append(interia)
    print("k:",k, " distance to closest centroid:", interia)
# Out:
# k: 1  distance to closest centroid: 227402.3837403076
# k: 2  distance to closest centroid: 183026.63510685612
# k: 3  distance to closest centroid: 152754.6963393438
# k: 4  distance to closest centroid: 140997.70053098947
# k: 5  distance to closest centroid: 132793.6453828494
# k: 6  distance to closest centroid: 125074.96398987636
# k: 7  distance to closest centroid: 118786.25969500584
# k: 8  distance to closest centroid: 114250.05953051057
# k: 9  distance to closest centroid: 109878.5248072044

# %%
plt.figure(figsize=(5,5))
plt.scatter(range(1, 10), interia_ls);
plt.plot(range(1, 10), interia_ls);

# %%
kmeans = KMeans(n_clusters=7)
# kmeans.fit(std_pl_X_ent)
# y_kmeans_ent = kmeans.predict(std_pl_X_ent)
kmeans.fit(pl_X_ent)
y_kmeans_ent = kmeans.predict(pl_X_ent)

# %%
centers_ent = kmeans.cluster_centers_

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_pl_X_ent = tsne.fit_transform(pl_X_ent)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 137247 samples in 7.782s...
# [t-SNE] Computed neighbors for 137247 samples in 3351.957s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 137247
# [t-SNE] Computed conditional probabilities for sample 2000 / 137247
# [t-SNE] Computed conditional probabilities for sample 3000 / 137247
# [t-SNE] Computed conditional probabilities for sample 4000 / 137247
# [t-SNE] Computed conditional probabilities for sample 5000 / 137247
# [t-SNE] Computed conditional probabilities for sample 6000 / 137247
# [t-SNE] Computed conditional probabilities for sample 7000 / 137247
# [t-SNE] Computed conditional probabilities for sample 8000 / 137247
# [t-SNE] Computed conditional probabilities for sample 9000 / 137247
# [t-SNE] Computed conditional probabilities for sample 10000 / 137247
# [t-SNE] Computed conditional probabilities for sample 11000 / 137247
# [t-SNE] Computed conditional probabilities for sample 12000 / 137247
# [t-SNE] Computed conditional probabilities for sample 13000 / 137247
# [t-SNE] Computed conditional probabilities for sample 14000 / 137247
# [t-SNE] Computed conditional probabilities for sample 15000 / 137247
# [t-SNE] Computed conditional probabilities for sample 16000 / 137247
# [t-SNE] Computed conditional probabilities for sample 17000 / 137247
# [t-SNE] Computed conditional probabilities for sample 18000 / 137247
# [t-SNE] Computed conditional probabilities for sample 19000 / 137247
# [t-SNE] Computed conditional probabilities for sample 20000 / 137247
# [t-SNE] Computed conditional probabilities for sample 21000 / 137247
# [t-SNE] Computed conditional probabilities for sample 22000 / 137247
# [t-SNE] Computed conditional probabilities for sample 23000 / 137247
# [t-SNE] Computed conditional probabilities for sample 24000 / 137247
# [t-SNE] Computed conditional probabilities for sample 25000 / 137247
# [t-SNE] Computed conditional probabilities for sample 26000 / 137247
# [t-SNE] Computed conditional probabilities for sample 27000 / 137247
# [t-SNE] Computed conditional probabilities for sample 28000 / 137247
# [t-SNE] Computed conditional probabilities for sample 29000 / 137247
# [t-SNE] Computed conditional probabilities for sample 30000 / 137247
# [t-SNE] Computed conditional probabilities for sample 31000 / 137247
# [t-SNE] Computed conditional probabilities for sample 32000 / 137247
# [t-SNE] Computed conditional probabilities for sample 33000 / 137247
# [t-SNE] Computed conditional probabilities for sample 34000 / 137247
# [t-SNE] Computed conditional probabilities for sample 35000 / 137247
# [t-SNE] Computed conditional probabilities for sample 36000 / 137247
# [t-SNE] Computed conditional probabilities for sample 37000 / 137247
# [t-SNE] Computed conditional probabilities for sample 38000 / 137247
# [t-SNE] Computed conditional probabilities for sample 39000 / 137247
# [t-SNE] Computed conditional probabilities for sample 40000 / 137247
# [t-SNE] Computed conditional probabilities for sample 41000 / 137247
# [t-SNE] Computed conditional probabilities for sample 42000 / 137247
# [t-SNE] Computed conditional probabilities for sample 43000 / 137247
# [t-SNE] Computed conditional probabilities for sample 44000 / 137247
# [t-SNE] Computed conditional probabilities for sample 45000 / 137247
# [t-SNE] Computed conditional probabilities for sample 46000 / 137247
# [t-SNE] Computed conditional probabilities for sample 47000 / 137247
# [t-SNE] Computed conditional probabilities for sample 48000 / 137247
# [t-SNE] Computed conditional probabilities for sample 49000 / 137247
# [t-SNE] Computed conditional probabilities for sample 50000 / 137247
# [t-SNE] Computed conditional probabilities for sample 51000 / 137247
# [t-SNE] Computed conditional probabilities for sample 52000 / 137247
# [t-SNE] Computed conditional probabilities for sample 53000 / 137247
# [t-SNE] Computed conditional probabilities for sample 54000 / 137247
# [t-SNE] Computed conditional probabilities for sample 55000 / 137247
# [t-SNE] Computed conditional probabilities for sample 56000 / 137247
# [t-SNE] Computed conditional probabilities for sample 57000 / 137247
# [t-SNE] Computed conditional probabilities for sample 58000 / 137247
# [t-SNE] Computed conditional probabilities for sample 59000 / 137247
# [t-SNE] Computed conditional probabilities for sample 60000 / 137247
# [t-SNE] Computed conditional probabilities for sample 61000 / 137247
# [t-SNE] Computed conditional probabilities for sample 62000 / 137247
# [t-SNE] Computed conditional probabilities for sample 63000 / 137247
# [t-SNE] Computed conditional probabilities for sample 64000 / 137247
# [t-SNE] Computed conditional probabilities for sample 65000 / 137247
# [t-SNE] Computed conditional probabilities for sample 66000 / 137247
# [t-SNE] Computed conditional probabilities for sample 67000 / 137247
# [t-SNE] Computed conditional probabilities for sample 68000 / 137247
# [t-SNE] Computed conditional probabilities for sample 69000 / 137247
# [t-SNE] Computed conditional probabilities for sample 70000 / 137247
# [t-SNE] Computed conditional probabilities for sample 71000 / 137247
# [t-SNE] Computed conditional probabilities for sample 72000 / 137247
# [t-SNE] Computed conditional probabilities for sample 73000 / 137247
# [t-SNE] Computed conditional probabilities for sample 74000 / 137247
# [t-SNE] Computed conditional probabilities for sample 75000 / 137247
# [t-SNE] Computed conditional probabilities for sample 76000 / 137247
# [t-SNE] Computed conditional probabilities for sample 77000 / 137247
# [t-SNE] Computed conditional probabilities for sample 78000 / 137247
# [t-SNE] Computed conditional probabilities for sample 79000 / 137247
# [t-SNE] Computed conditional probabilities for sample 80000 / 137247
# [t-SNE] Computed conditional probabilities for sample 81000 / 137247
# [t-SNE] Computed conditional probabilities for sample 82000 / 137247
# [t-SNE] Computed conditional probabilities for sample 83000 / 137247
# [t-SNE] Computed conditional probabilities for sample 84000 / 137247
# [t-SNE] Computed conditional probabilities for sample 85000 / 137247
# [t-SNE] Computed conditional probabilities for sample 86000 / 137247
# [t-SNE] Computed conditional probabilities for sample 87000 / 137247
# [t-SNE] Computed conditional probabilities for sample 88000 / 137247
# [t-SNE] Computed conditional probabilities for sample 89000 / 137247
# [t-SNE] Computed conditional probabilities for sample 90000 / 137247
# [t-SNE] Computed conditional probabilities for sample 91000 / 137247
# [t-SNE] Computed conditional probabilities for sample 92000 / 137247
# [t-SNE] Computed conditional probabilities for sample 93000 / 137247
# [t-SNE] Computed conditional probabilities for sample 94000 / 137247
# [t-SNE] Computed conditional probabilities for sample 95000 / 137247
# [t-SNE] Computed conditional probabilities for sample 96000 / 137247
# [t-SNE] Computed conditional probabilities for sample 97000 / 137247
# [t-SNE] Computed conditional probabilities for sample 98000 / 137247
# [t-SNE] Computed conditional probabilities for sample 99000 / 137247
# [t-SNE] Computed conditional probabilities for sample 100000 / 137247
# [t-SNE] Computed conditional probabilities for sample 101000 / 137247
# [t-SNE] Computed conditional probabilities for sample 102000 / 137247
# [t-SNE] Computed conditional probabilities for sample 103000 / 137247
# [t-SNE] Computed conditional probabilities for sample 104000 / 137247
# [t-SNE] Computed conditional probabilities for sample 105000 / 137247
# [t-SNE] Computed conditional probabilities for sample 106000 / 137247
# [t-SNE] Computed conditional probabilities for sample 107000 / 137247
# [t-SNE] Computed conditional probabilities for sample 108000 / 137247
# [t-SNE] Computed conditional probabilities for sample 109000 / 137247
# [t-SNE] Computed conditional probabilities for sample 110000 / 137247
# [t-SNE] Computed conditional probabilities for sample 111000 / 137247
# [t-SNE] Computed conditional probabilities for sample 112000 / 137247
# [t-SNE] Computed conditional probabilities for sample 113000 / 137247
# [t-SNE] Computed conditional probabilities for sample 114000 / 137247
# [t-SNE] Computed conditional probabilities for sample 115000 / 137247
# [t-SNE] Computed conditional probabilities for sample 116000 / 137247
# [t-SNE] Computed conditional probabilities for sample 117000 / 137247
# [t-SNE] Computed conditional probabilities for sample 118000 / 137247
# [t-SNE] Computed conditional probabilities for sample 119000 / 137247
# [t-SNE] Computed conditional probabilities for sample 120000 / 137247
# [t-SNE] Computed conditional probabilities for sample 121000 / 137247
# [t-SNE] Computed conditional probabilities for sample 122000 / 137247
# [t-SNE] Computed conditional probabilities for sample 123000 / 137247
# [t-SNE] Computed conditional probabilities for sample 124000 / 137247
# [t-SNE] Computed conditional probabilities for sample 125000 / 137247
# [t-SNE] Computed conditional probabilities for sample 126000 / 137247
# [t-SNE] Computed conditional probabilities for sample 127000 / 137247
# [t-SNE] Computed conditional probabilities for sample 128000 / 137247
# [t-SNE] Computed conditional probabilities for sample 129000 / 137247
# [t-SNE] Computed conditional probabilities for sample 130000 / 137247
# [t-SNE] Computed conditional probabilities for sample 131000 / 137247
# [t-SNE] Computed conditional probabilities for sample 132000 / 137247
# [t-SNE] Computed conditional probabilities for sample 133000 / 137247
# [t-SNE] Computed conditional probabilities for sample 134000 / 137247
# [t-SNE] Computed conditional probabilities for sample 135000 / 137247
# [t-SNE] Computed conditional probabilities for sample 136000 / 137247
# [t-SNE] Computed conditional probabilities for sample 137000 / 137247
# [t-SNE] Computed conditional probabilities for sample 137247 / 137247
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.676750
# [t-SNE] Error after 300 iterations: 5.045705

# %%
plt.figure(figsize=(16,10))
plt.scatter(tsne_pl_X_ent[:, 0], tsne_pl_X_ent[:, 1], c=y_kmeans_ent, s=1, cmap='viridis')

# %%
centers_ent.shape
# Out:
# (7, 388)

# %%
for c_idx in range(len(centers_ent)):
    
    x = centers_ent[c_idx]
    n_groups = 388

    
    fig, ax = plt.subplots(figsize=(20, 3))
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] + ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(16)

    index = np.arange(n_groups)
    bar_width = 0.30

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    
    rects1 = ax.bar(index, x, bar_width,
                    alpha=opacity, color='rgbkymc', 
                    error_kw=error_config,
                    label='playlist features')
    ax.axhline(0, color='gray')
    

#     ax.set_xlabel(str(c_idx))
    ax.set_ylabel(str(c_idx))
    ax.set_ylim(bottom=0, top=1)
#     ax.set_xticks(index + bar_width / 2)
#     ax.set_xticklabels(feature_name_list, rotation=60)
    ax.legend()
    fig.tight_layout()
    plt.savefig('./data_pl_dzrmeta/cnt_' + str(c_idx) + '.png')

# %%
clustered_titles_ent = [[] for _ in range(7)]
for _idx in range(len(y_kmeans_ent)):
    curr_label = y_kmeans_ent[_idx]
    clustered_titles_ent[curr_label].append(pl_Y_title_dict[str(pl_key_to_id_dict[str(_idx)])])

# %%
print(clustered_titles_ent[1][:50]) # High entropy for genre / mood:emotion
# Out:
# ['bop', "1990's", 'rap', 'rock alternativo', 'alexia', 'relax', 'june', 'car', '90s baby', 'intro', 'wedding cocktail hour', 'mix tape', 'sleep', 'mood', 'sugar', 'chill', 'the playlist', 'counting crows', 'pool party', 'rock', 'bk', 'hood', 'chill jams', "just chillin'", 'beatles', 'meditate', 'sleeps', 'yacht rock', 'classics', "90's", 'band', 'throwbacks', 'chilling', 'rock', 'sleeping songs', 'smr', 'soft rock', 'flash back', '2014', 'lunes', 'gym workout', 'max', 'um', 'middle school', 'go-to', 'go to', 'mood', 'country', 'zombies', 'downtempo']

# %%
print(clustered_titles_ent[0][:50])
# Out:
# ['zoned', 'rap classics', 'kendrick lamar', 'rap god', 'blackout', 'rap', 'chill out', 'issa playlist', "vibin'", 'cody', 'rap', 'the mix', 'rap', 'lit', 'pump up', "summer '16", 'beautiful', 'bruno mars', 'new2', 'kodak black', 'j cole', 'september', 'old bops', 'booty', 'lit', 'drugs', 'hip-hop', 'bumpin', 'snowboarding', 'summer', 'chill', 'spotify me', 'beast mode', 'rap', 'jesse', 'vibes', 'ash', 'paradise', 'hype', 'cool', 'praise and worship', 'rap', 'house', 'default', 'party', 'lowkey', 'bars', 'punk', 'vibes', 'lit']

# %%
print(clustered_titles_ent[2][:50])
# Out:
# ['✔️', 'disneyland', 'luv', 'worship', 'chill beats', 'everyday', 'get pumped', 'phone', 'hyphy', 'eminem', 'feels', 'christmastime', 'workout', 'grind', 'raw', 'swing', 'ghetto', 'ha', 'country', 'fix you', 'the greatest', 'lit af', 'christian', 'shower', 'summer 17', 'painting', 'billy', 'praise', 'im', 'fire', '2017', 'high school', 'yaaas', 'sad song', 'holiday party', 'recent', 'hypebeast', 'lit', 'other', '⚡️', 'hype', 'friday', 'hip hop', 'sex', 'car', 'ups', 'christ', 'etc', 'turn up', 'preach']

# %%
for _i in range(7):
    print(clustered_titles_ent[_i][:100])
    print()
# Out:
# ['zoned', 'rap classics', 'kendrick lamar', 'rap god', 'blackout', 'rap', 'chill out', 'issa playlist', "vibin'", 'cody', 'rap', 'the mix', 'rap', 'lit', 'pump up', "summer '16", 'beautiful', 'bruno mars', 'new2', 'kodak black', 'j cole', 'september', 'old bops', 'booty', 'lit', 'drugs', 'hip-hop', 'bumpin', 'snowboarding', 'summer', 'chill', 'spotify me', 'beast mode', 'rap', 'jesse', 'vibes', 'ash', 'paradise', 'hype', 'cool', 'praise and worship', 'rap', 'house', 'default', 'party', 'lowkey', 'bars', 'punk', 'vibes', 'lit', "90's hip hop", 'beats', 'rap', '2k17', 'whippin', 'mix', 'throwback', 'good', 'rap 2 0', 'kevin gates', 'tyler the creator', 'new favorites', 'lit playlist', 'rap', 'boom', 'turn up', 'yum', 'gym flow', 'drivin', '\U0001f98b\U0001f98b\U0001f98b', 'vietnam', 'sabotage', 'rap', 'ya know', 'hippy', 'chill', 'jam', 'turnip', '👏🏻', 'fire', 'summer 16', 'sports', 'chance', '90s', '🔥🔥', 'bpm', 'a1', 'rap', 'rap', 'rap', 'new', 'party', '💎💎💎', 'my favs', 'girl power', 'summer 16', 'vibe', 'tyler the creator', 'car', 'chill']
#
# ['bop', "1990's", 'rap', 'rock alternativo', 'alexia', 'relax', 'june', 'car', '90s baby', 'intro', 'wedding cocktail hour', 'mix tape', 'sleep', 'mood', 'sugar', 'chill', 'the playlist', 'counting crows', 'pool party', 'rock', 'bk', 'hood', 'chill jams', "just chillin'", 'beatles', 'meditate', 'sleeps', 'yacht rock', 'classics', "90's", 'band', 'throwbacks', 'chilling', 'rock', 'sleeping songs', 'smr', 'soft rock', 'flash back', '2014', 'lunes', 'gym workout', 'max', 'um', 'middle school', 'go-to', 'go to', 'mood', 'country', 'zombies', 'downtempo', 'summer 2016', 'hard rock', 'adventures', 'relax', 'work flow', 'wedding background music', 'nostalgia', '1992', 'unstoppable', "vibin'", 'the metal', "road trippin'", 'summer 2014', 'june17', 'yacht rock', 'chick music', 'sleep', 'xmas', 'rock alternative', 'mood', '👌🏼👌🏼', 'coldplay', 'back in the day', 'miley cyrus – bangerz deluxe version', 'chill', '80s rock', 'game on', 'rock of ages', 'soothing', 'the best', 'workout music', 'top 25', 'summer 16', 'simp', "90's rock", 'ambient', 'playlist', 'salsa', 'far away', 'acoustic', 'hi', 'instrumental', 'workout', 'oct 17', 'clasic', 'sweet love', 'throwback', 'mcfly', 'old rock', 'nature sounds']
#
# ['✔️', 'disneyland', 'luv', 'worship', 'chill beats', 'everyday', 'get pumped', 'phone', 'hyphy', 'eminem', 'feels', 'christmastime', 'workout', 'grind', 'raw', 'swing', 'ghetto', 'ha', 'country', 'fix you', 'the greatest', 'lit af', 'christian', 'shower', 'summer 17', 'painting', 'billy', 'praise', 'im', 'fire', '2017', 'high school', 'yaaas', 'sad song', 'holiday party', 'recent', 'hypebeast', 'lit', 'other', '⚡️', 'hype', 'friday', 'hip hop', 'sex', 'car', 'ups', 'christ', 'etc', 'turn up', 'preach', 'jesus', 'winter', 'just chillin', '👸🏼', 'rock', "'tis the season", 'you', 'rap', 'turnt', 'turnt', 'turnt', "vibin'", 'chill', '> <', 'metal', 'fall vibes', 'jesus time', 'the weeknd', 'lit', 'controlla', 'pogo', 'rap', 'christmas jams', 'yes', 'shoegaze', 'shower', 'christian', 'ella', 'rap', 'chris brown', 'rap', 'feelin it', 'workout', 'dank', '😎😎😎', 'lift', 'rapz', 'freaky', 'party time', 'christmas', 'boolin', 'lol', 'fuego', 'partay', 'old school', 'work out songs', 'classics', 'calm', 'feels', 'litty titty']
#
# ['country', 'country', 'sleep', 'bruno mars', 'more songs', 'chill music', 'indy', 'sad', 'workout', 'yeah', 'no', 'petrichor', 'country', 'dubstep', 'golden', 'end of summer', 'house', 'damn', 'the glitch mob', 'other', 'happy chill', 'sadness', 'christmas', 'sam', 'jesus music', 'sorry', 'the game', 'chill', 'country lovin', 'wake up', 'september 2014', 'stuff', 'emo', 'funk', 'mood music', 'july', 'summer 2014', 'summer', 'any', 'for now', 'mixtape', 'sophie', 'drag', 'september', 'panic', 'justin bieber – purpose deluxe', 'john mayer', 'chill', 'shower', 'boyz', '͡° ͜ʖ ͡°', 'car', 'reggae', 'the fault in our stars music from the motion picture', 'lol', '❤️', 'hm', 'feels', 'rock', 'cheel', 'fake', 'summer 2016', 'electronic', 'cool vibes', 'ego', 'screamo', 'bounce', 'line dances', 'rock pop', 'just breathe', 'chill', 'call me maybe', 'amv', 'wedding playlist', 'work out', 'summer house', 'that good good', 'plane', 'country', '😂😂', 'boppin', 'alternativo', 'vibes', 'tight', 'country', 'reggaeton', 'sxsw', 's3rl', 'edm', 'lit lit', 'trolls', 'new new', 'fu', 'ray', 'hb', 'commute', 'country', 'get up and dance', 'league', 'nov']
#
# ['i put a spell on you', 'spring 2016', 'smooth jazz', 'workout', 'tom petty', 'jazzy', 'workout', 'mayer', "music from baz luhrmann's film the great gatsby", 'traveling', '⚡️', '1967', 'homework', 'modern rock', 'sound', 'pop', 'english', 'dance yrself clean', 'top down', 'christmas', 'bass', 'the playlist', 'oldies', 'waves', 'mad', 'winter 2015', 'mood', 'rage', 'leggo', 'late', 'christmas', 'europe', 'summa 16', 'groove', 'workout mix', 'party', 'revolution', 'music', 'play it forward', 'drive time', 'rap', '1 playlist', 'op', 'yeezy taught me', 'beach', 'drive home', 'feel good', 'days', 'ash', 'pop', 'party', 'makeup', 'get lucky', 'elijah', 'workout', 'oldies', 'jammy jams', 'r&b', 'bad girls', 'may 2014', 'forrest gump', 'heavy metal', 'one hit wonders', 'mara', 'beep beep', 'work out', 'post punk', 'banana', 'bumpin', 'country', 'hurt', 'folk yeah', '2000', 'um', 'fb', 'vibin', 'chill vibes', 'its lit', 'ceremony music', '13 1', 'arctic monkeys', 'ceremony', 'workout playlist', 'new', 'r&b', 'uh', 'october 2015', 'love', 'blah', 'ye', 'workout', 'jock jams', 'hype', '1982', 'singing songs', 'fam', 'divas', 'snowboarding', 'cardio', 'nye']
#
# ["90's", 'sad songs', 'twenty one pilots', 'angst', 'kevin', 'ski', 'its lit', '🤘🏼', 'emotional', 'bang bang', 'pump', 'motown', 'wes anderson', 'chill alternative', 'classics', '90s hits', 'elisa', '90s', 'rawr', 'upbeat', '90s alternative', 'dance mix', 'cruisin', 'breezeblocks', 'classic rock', 'chill', 'congratulations', 'sad songs', 'housewarming', "90's", 'melting pot', 'sleep', '14', 'calming music', 'rock', 'oldies', 'classic', 'for you', 'december', 'chill time', 'party', 'summer country', 'kitchen', 'mellow', 'the classics', 'chill', 'christmas favorites', 'working out', 'old rock', 'rock', 'halloweenie', 'rock', 'michelle', 'old', 'moo', 'rock', 'dad', 'r&b classics', 'julie', 'old', "90's music", 'punk', "90's", '90s rock', 'happy', 'sad', 'from me to you', '80s pop', 'hotel california', 'stuff', 'alternative', 'feels', "90's hits", 'fall', 'rock alt', "70's", 'oldies', 'summer camp', 'dad rock', '5k', 'chill music', 'bbq', 'suicide squad', 'island vibes', 'sound of silence', 'yoga', '2015 top tracks', 'moms', 'lol', 'lounge', "70's", "90's kids", 'smooth rock', 'rock', '🤘🏻', 'gym rock', 'summer', 'pool', 'wake', 'trip']
#
# ['sleep', 'new songs', 'smooth', 'art class', 'cr', 'run', 'ouch', 'musicals', 'shower', 'worship', 'rent', 'worship', 'deep thoughts', 'country', 'classical favorites', 'christian music', 'mood music', 'good music', 'sundays', 'worship', 'jack & jack', 'car', 'rock', 'airplane mode', 'worship music', 'country', 'worship', 'favorite worship', 'l o v e', 'worship', 'post rock', 'feels', 'good stuff', 'christian music', '2017 summer', 'country 1', 'worship', 'kids songs', 'funk', 'jesus', 'love', '⭐️', 'chill rap', 'grandpa', 'jesus jamz', 'country', 'les misérables the motion picture soundtrack deluxe', 'love sucks', 'chill', '4th of july', 'country ❤️', 'bryson tiller', 'christmas', 'sleep', 'christmas', 'sunset', 'pre', 'logic', 'pause', 'christmas', '☀️☀️☀️', 'jesus jams', 'country', 'les miserables', 'comedy', 'lll', 'ncs', 'trolls', 'here', 'tvd', 'god is good', 'slytherin', 'odd future', 'summer', 'christmas', 'lenny', 'country', 'nocopyrightsounds', 'aquarius', 'camp', 'jack and jack', 'worship', 'walking', 'ceremony', 'rap', 'christmas jamz', 'christmas 2015', 'biking', 'country', 'good', 'worship', 'musicals', 'spooky', 'bethel music', 'hillsong', 'musicals', 'good music', 'twilight', 'sleep', 'rebelution']

# %%
print(len(clustered_titles_ent[6]))
# Out:
# 16229

# %%
print(clustered_titles_ent[6])
# Out:
# ['sleep', 'new songs', 'smooth', 'art class', 'cr', 'run', 'ouch', 'musicals', 'shower', 'worship', 'rent', 'worship', 'deep thoughts', 'country', 'classical favorites', 'christian music', 'mood music', 'good music', 'sundays', 'worship', 'jack & jack', 'car', 'rock', 'airplane mode', 'worship music', 'country', 'worship', 'favorite worship', 'l o v e', 'worship', 'post rock', 'feels', 'good stuff', 'christian music', '2017 summer', 'country 1', 'worship', 'kids songs', 'funk', 'jesus', 'love', '⭐️', 'chill rap', 'grandpa', 'jesus jamz', 'country', 'les misérables the motion picture soundtrack deluxe', 'love sucks', 'chill', '4th of july', 'country ❤️', 'bryson tiller', 'christmas', 'sleep', 'christmas', 'sunset', 'pre', 'logic', 'pause', 'christmas', '☀️☀️☀️', 'jesus jams', 'country', 'les miserables', 'comedy', 'lll', 'ncs', 'trolls', 'here', 'tvd', 'god is good', 'slytherin', 'odd future', 'summer', 'christmas', 'lenny', 'country', 'nocopyrightsounds', 'aquarius', 'camp', 'jack and jack', 'worship', 'walking', 'ceremony', 'rap', 'christmas jamz', 'christmas 2015', 'biking', 'country', 'good', 'worship', 'musicals', 'spooky', 'bethel music', 'hillsong', 'musicals', 'good music', 'twilight', 'sleep', 'rebelution', 'hillsong', 'countryyy', 'norah jones', 'stargazing', 'christmas 2017', 'christian', 'drive', 'worship', 'indie', 'christian', 'stuff', 'throwbacks', 'grateful dead', 'darling', 'alex', 'worship', 'wedding', 'youth', 'banjo', 'babes', 'christian songs', 'alicia', 'hypeee', 'no doubt', 'done', 'jesus', 'music', 'jesus jams', '13', 'travel', 'worship', 'breathe', 'alt indie', 'shower', 'casting crowns', 'funk', 'opening', 'worship', 'jesus', 'zzzzz', '17', 'chill', '✝️', 'christan', 'lit', 'indie', '🖖🏽', 'i know', 'beatz', 'blacklist', 'chill', 'warped tour 2016', 'here we go', 'believe', '👌🏻', 'les mis', 'bachata', '5sos', 'hhhhh', 'country', 'tv', 'choreography', 'vibes', 'southern', 'josh garrels', 'old school', 'dance', 'christian', 'country', 'lotr', 'fall 16', 'musicals', 'the lacs', 'roadtrip', 'guitar', 'slideshow', 'acoustic covers', 'sleep', 'true love', 'jess', 'jesus', 'wavy', 'autumn', 'metal', 'something different', 'country', 'naruto', 'chill', 'personal', 'kids songs', 'rockin', 'sam', 'worship', 'mexican songs', 'para estudiar', 'country', 'classical', 'cake', 'bachata', 'musicals', 'yoga', '<3', 'uplifting', 'jazzy jazz', 'mornings', 'singer songwriter', '02', "august '16", 'christian', 'sunday music', 'romeo santos', 'relax', 'worship', 'g-eazy', 'jaa', 'she', 'encounter', 'movie music', 'dreams', 'egg', 'worship', 'pop punk', 'baby makin music', 'gnash', 'good', 'chance', 'hope', 'instrumental', 'downtempo', 'alexander hamilton', 'in the mood', 'musicals', 'christian', '☺️', 'christian music', 'my feels', 'alison', 'country', 'worship', 'sad', 'les misérables', 'day 1', 'new playlist 3', 'new', 'hero', 'comedy', '🤘🏻', '1st', 'country rap', 'pump up', 'worship', 'acoustic', 'chill', 'twilight', 'i miss you', 'chill 2', 'harry potter', 'coffee house', 'worship', 'christian', 'sunday morning', 'king lil g', 'worship music', 'country', 'jesus jams', 'merry chrysler', 'xxx', 'asdfghjkl', 'chill', 'acoustic worship', 'hamilton', 'undertale', 'beach', 'travis scott', 'mine', 'set list', 'moana', "summer '16", 'fall 2016', 'los angeles', 'chill', 'spring break', 'logic', 'christian', 'playlist', 'slow rock', 'praise', 'ball', 'god', 'sunday', 'young dumb & broke', 'december', 'finals', '2 0 1 5', 'coolin', 'christian music', 'country', 'worship music', 'summer', 'driving', 'camp 2017', 'chill', 'spanish music', 'sunday', 'worship', 'les misérables', 'july', 'alt', 'spring 2016', 'youth', 'dance', 'ev', 'country', 'body like a back road', 'cultura profetica', 'new hip hop', 'harry potter', 'run', 'the feels', 'power hour', 'stone', 'bb', 'gospel', 'god is love', 'worship', 'logic', 'love song', 'dope', 'worship', 'chill rap', 'music', 'walk', 'thing', 'paige', 'fav songs', 'faith', 'disney', 'country', 'gos ...
