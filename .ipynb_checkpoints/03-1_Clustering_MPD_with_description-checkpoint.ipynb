# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
import pickle
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.manifold import TSNE
from sklearn import preprocessing

np.set_printoptions(suppress=True)

# %%
# sns.reset_orig
import importlib
importlib.reload(plt); importlib.reload(sns)
# Out:
# <module 'seaborn' from '/home/kaka/p35_tf16_k205/lib/python3.5/site-packages/seaborn/__init__.py'>

# %%
sns.reset_orig()
# Out:
# /home/kaka/p35_tf16_k205/lib/python3.5/site-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)
# /home/kaka/p35_tf16_k205/lib/python3.5/site-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))

# %%
def save_obj_curr_folder(obj, name):
    with open(name, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj_curr_folder(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
pl_X = load_obj_curr_folder('data_pl/pl_X.p')
pl_Y_desc = load_obj_curr_folder('data_pl/pl_Y_desc.p')
pl_Y_title = load_obj_curr_folder('data_pl/pl_Y_title.p')

# %%
pl_X = np.array(pl_X)

# %%
pl_X.shape
# Out:
# (18760, 26)

# %%
std_pl_X = preprocessing.scale(pl_X, axis=0)

# %%
std_pl_X[0]
# Out:
# array([ 0.76299574,  0.79342741, -0.42116335, -0.82826443, -0.46744253,
#        -1.0754256 , -0.17647158, -0.75766247,  0.07050978, -0.70373644,
#        -0.10961879, -0.16685067,  1.17448495, -0.01782352,  1.02434481,
#        -0.44407006, -1.15906514,  0.70483631, -0.61232168,  1.26351278,
#        -0.81933179,  0.89624595,  1.33397921,  1.66840684,  0.92186491,
#         0.        ])

# %%
np.mean(std_pl_X[:, 10]), np.mean(std_pl_X[10, :])
# Out:
# (8.037132201178286e-13, -0.30146021970066755)

# %%
for _i in range(26):
    print(np.mean(std_pl_X[:, _i]))
# Out:
# 5.57223066551311e-15
# -3.761028446747226e-15
# 3.3996970128905435e-15
# 1.2551154145851918e-14
# 2.631962404475979e-15
# 1.0492246730291202e-14
# -1.8112969072967693e-14
# -1.2915515612696917e-15
# 1.5074035362748522e-14
# 1.9911861782718544e-14
# 8.037132201178286e-13
# 1.0844109311059397e-14
# 2.0157294454772137e-15
# -1.94914447055897e-14
# -4.7117012968313676e-15
# -5.1249220456129616e-15
# -4.574592304110069e-15
# -1.5784956852632163e-14
# 1.162017651019183e-15
# 1.9697486948795186e-14
# -3.3115419906367246e-14
# 1.7112111301514566e-15
# -1.6665181435737957e-17
# 3.7117904106870906e-17
# 2.2725247412369942e-17
# 0.0

# %%
print(len(std_pl_X[:, 10]), len(std_pl_X[10, :]))
# Out:
# 18760 26

# %%
A = std_pl_X
interia_ls = []
for k in range (1, 20):
    # Create a kmeans model on our data, using k clusters.  random_state helps ensure that the algorithm returns the same results each time.
    kmeans_model = KMeans(n_clusters=k, random_state=1).fit(A)

    # These are our fitted labels for clusters -- the first cluster has label 0, and the second has label 1.
    labels = kmeans_model.labels_

    # Sum of distances of samples to their closest cluster center
    interia = kmeans_model.inertia_
    interia_ls.append(interia)
    print("k:",k, " distance to closest centroid:", interia)
# Out:
# k: 1  distance to closest centroid: 468999.99999999994
# k: 2  distance to closest centroid: 387641.82951136504
# k: 3  distance to closest centroid: 357084.8974179473
# k: 4  distance to closest centroid: 330367.84729641967
# k: 5  distance to closest centroid: 308606.3386381082
# k: 6  distance to closest centroid: 289682.6716915468
# k: 7  distance to closest centroid: 278591.1516667612
# k: 8  distance to closest centroid: 268867.45582871547
# k: 9  distance to closest centroid: 260718.1034849374
# k: 10  distance to closest centroid: 254287.59606673932
# k: 11  distance to closest centroid: 248701.71540491216
# k: 12  distance to closest centroid: 243285.4536030041
# k: 13  distance to closest centroid: 238265.38578002682
# k: 14  distance to closest centroid: 233673.36438753246
# k: 15  distance to closest centroid: 229864.99629608894
# k: 16  distance to closest centroid: 226683.34674893215
# k: 17  distance to closest centroid: 223712.22566905906
# k: 18  distance to closest centroid: 220759.55209059367
# k: 19  distance to closest centroid: 218026.19660328195

# %%
plt.figure(figsize=(5,5))
plt.scatter(range(1, 20), interia_ls);
plt.plot(range(1, 20), interia_ls);

# %%
# we choose k = 6

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_pl_X = tsne.fit_transform(std_pl_X)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 18760 samples in 0.017s...
# [t-SNE] Computed neighbors for 18760 samples in 12.859s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 18760
# [t-SNE] Computed conditional probabilities for sample 2000 / 18760
# [t-SNE] Computed conditional probabilities for sample 3000 / 18760
# [t-SNE] Computed conditional probabilities for sample 4000 / 18760
# [t-SNE] Computed conditional probabilities for sample 5000 / 18760
# [t-SNE] Computed conditional probabilities for sample 6000 / 18760
# [t-SNE] Computed conditional probabilities for sample 7000 / 18760
# [t-SNE] Computed conditional probabilities for sample 8000 / 18760
# [t-SNE] Computed conditional probabilities for sample 9000 / 18760
# [t-SNE] Computed conditional probabilities for sample 10000 / 18760
# [t-SNE] Computed conditional probabilities for sample 11000 / 18760
# [t-SNE] Computed conditional probabilities for sample 12000 / 18760
# [t-SNE] Computed conditional probabilities for sample 13000 / 18760
# [t-SNE] Computed conditional probabilities for sample 14000 / 18760
# [t-SNE] Computed conditional probabilities for sample 15000 / 18760
# [t-SNE] Computed conditional probabilities for sample 16000 / 18760
# [t-SNE] Computed conditional probabilities for sample 17000 / 18760
# [t-SNE] Computed conditional probabilities for sample 18000 / 18760
# [t-SNE] Computed conditional probabilities for sample 18760 / 18760
# [t-SNE] Mean sigma: 0.986628
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 93.621674
# [t-SNE] Error after 300 iterations: 3.794931

# %%
kmeans = KMeans(n_clusters=6)
kmeans.fit(std_pl_X)
y_kmeans = kmeans.predict(std_pl_X)

# %%
centers = kmeans.cluster_centers_

# %%
centers.shape
# Out:
# (6, 26)

# %%
plt.figure(figsize=(16,10))
plt.scatter(tsne_pl_X[:, 0], tsne_pl_X[:, 1], c=y_kmeans, s=1, cmap='viridis')

# %%
k_spec = 10
spec_model = SpectralClustering(n_clusters=k_spec, affinity='nearest_neighbors', assign_labels='kmeans')
spec_labels = spec_model.fit_predict(std_pl_X)

# %%
len(spec_labels)
# Out:
# 18760

# %%
plt.figure(figsize=(16,10))
plt.scatter(tsne_pl_X[:, 0], tsne_pl_X[:, 1], c=spec_labels,
            s=1, cmap='viridis');

# %%
len(y_kmeans)
# Out:
# 18760

# %%
clustered_titles = [[] for _ in range(6)]
clustered_descriptions = [[] for _ in range(6)]
for _idx in range(len(y_kmeans)):
    curr_label = y_kmeans[_idx]
    clustered_titles[curr_label].append(pl_Y_title[_idx])
    clustered_descriptions[curr_label].append(pl_Y_desc[_idx])

# %%
for _i in range(len(clustered_descriptions)):
    print(len(clustered_descriptions[_i]))
# Out:
# 2633
# 4503
# 4518
# 2810
# 3636
# 660

# %%
print(clustered_descriptions[-1])
# Out:
# ['The best from the movies', '(listen in order not on shuffle)', 'I grew older. I saw it in a dream.', 'From my catalogue, tracks to dance to!', 'instrumentals', 'Songs for a poor lonesome cowboy.', 'Immerse yourself into Westeros, Middle Earth, and the world of Pirates of the Carribbean as you study for homework, midterms, and finals.', 'I use this playlist when I do studious stuff I guess.', 'cute', '2017', 'warm n fuzzy', 'Instrumental Worship music -- Piano and Guitar, gospel and contemporary worship.', 'Warning: Chills may follow.', 'soundtracks from all blockbuster hit movies', 'get work done but also get work done while listening to some nice tunes', 'some songs to help you focus - credits to lovely suggestions', 'Music to listen too when planning a castle raid or killing a great dragon!!!', 'Motivation to finish exams, studying, yardwork, etc. 10+ years of curating and 20+ years of watching movies/TV shows have gone into this playlist. Please enjoy and message me any recommendations.', "classical, romantic, baroque - all your true music necessities. sitting to hear a live performance, and that indescribable feeling. hear listen, appreciate, and you'll understand why classical music is a passion.", 'these songs are claming', 'the actual best collection of the most beautiful music to ever be.', 'some of my favorites, updated regularly!', 'This playlist includes post rock and alternative songs perfect for relaxing and concentrating', 'songs to drift away to with your body curled up next to mine', "All of these composers were found using the key word &quot;Forgotten Composer&quot; on Harvard's amalgamated digital databases.", 'A full collected set of all 8 offical movie soundtracks in one great place spanding over 9 hours of total music time. This is one of the best soundtracks for the most dedicated of fans.', 'In preparation for the first listening quiz of the year, study this very brief playlist introducing you to some giants of the Renaissance.', 'Soundtracks from The Theory of Everything, The Imitation Game, The Danish Girl, Interstellar, Fantastic Beasts and Where to FInd Them, select tracks from the Harry Potter films and Game of Thrones series, and a dash of essential classical pieces', 'NATURE SOUNDS ANOTHER VERSION OF EARTH SOUNDS', 'Just some good soundstrack music and other stuff', 'for studying, for reflection, for meditation, for introspection, for journalling, for gentleness, for relaxation, for anything that fits for you.', 'the secret to a 4.0 GPA', 'I am a nerd, but these songs do sound good!', 'Studying and Feelz', "New and improved! I've added some more songs and taken out the ones that get a little too loud to be lullabies. Enjoy :3", 'BOUND237', 'plane rides, car rides, train rides, etc.', 'sleepy time', 'leave me alone', 'ost, piano, instrumental, jazz, study, sleep, relax', 'A peaceful and introspective playlist to create a relaxing atmosphere.', 'trying my best', 'Prelude, Bridal Party Walk-In, Bride Enterance Song, and Exit Song', "“I love sleep. My life has the tendency to fall apart when I'm awake, you know?”  ― Ernest Hemingway // when all esle fails, get in bed xx", 'may your mind and heart be one..', 'songs with jazz aspects', 'Jazz is life. What a wonderful genre.', 'Music favorites from the Pirates Of The Caribbean. Plus, the new soundtrack gets the full album in this playlist because it rocks!', 'for the scholar, the dreamer, the pianist, the romantic.', 'Comprised of selections from primarily college level marching bands, this marching band playlist has the largest collection of soley marching music. Everyone loves a good drumline or brass band, but this playlist stays true to the whole band!', 'blue, pink, brown, and some white', 'Great music', 'Prepare to meet your foes.', 'My favorite music from video games and from my favorite band(s)', 'All songs from The Hobbit ( Mostly by Howard Shore ) and a couple of different songs by Peter Hollens that are based on The Hobbit! I See Fire by Ed  ...

# %%
centers
# Out:
# array([[ 0.07680886, -0.41079258,  0.21749473,  0.40548636, -0.17298816,
#          0.06772523,  0.38202405,  0.01216539,  0.1413856 ,  0.22507609,
#          0.09067348,  0.32638246, -0.11604584,  0.11493757,  0.0051719 ,
#          0.01445683,  0.1826938 , -0.20082662,  0.19563475,  0.00698619,
#          0.30587787, -0.00304622,  1.80673221,  1.77457228,  1.66679174,
#          0.        ],
#        [-0.25082455,  0.7607265 , -0.48844614, -0.74231172,  0.14031292,
#         -0.60034755, -0.38516686, -0.49185623, -0.43515144, -0.7122431 ,
#          0.36633049, -0.02057935,  0.9654681 ,  0.23133096,  0.6378268 ,
#          0.40594223, -0.569387  ,  0.40399659, -0.37125948,  0.19450981,
#         -0.24201257, -0.198964  , -0.3599305 , -0.28876709, -0.37493805,
#          0.        ],
#        [-0.0974439 , -0.7853911 ,  0.0444028 ,  0.93106681, -0.17784178,
#          0.34997068,  0.74448552, -0.28865979,  0.50403759,  0.35958722,
#          0.25822826,  0.07651075, -0.83850403, -0.6167206 , -0.70630735,
#         -0.20453621,  0.26239941, -0.74446227, -0.34504133, -0.38810243,
#         -0.17010654, -0.3221413 , -0.3482286 , -0.37138963, -0.33473502,
#          0.        ],
#        [-0.21595982,  0.38996498, -0.35198956, -0.17855951, -0.0444274 ,
#          0.31778059, -0.53903045, -0.54277625,  0.05762911,  0.84954422,
#         -1.72092343, -0.04260162,  0.45926168,  0.58503263,  0.80613247,
#          0.25334654,  0.50852684,  0.67941251, -0.45100736,  0.11816749,
#          0.70173591,  1.45394981, -0.16991396, -0.15088481, -0.19880082,
#          0.        ],
#        [ 0.80246287, -0.42382247,  1.06717918,  0.05371521, -0.44893583,
#          0.15995435,  0.33387641,  1.51732578,  0.0452969 , -0.0305473 ,
#          0.51819734, -0.07420441, -0.43987751, -0.18147981, -0.55131969,
#         -0.69201875,  0.00172006, -0.44418427,  1.27528238,  0.03644825,
#         -0.0490363 , -0.53679043, -0.20890054, -0.25728274, -0.12577025,
#          0.        ],
#        [-1.4319041 ,  2.49898609, -2.22249663, -2.46045894,  3.6134191 ,
#         -0.80391317, -3.53619522, -0.76991567, -1.53955406, -1.94774733,
#         -0.15767108, -1.094398  ,  0.08363876,  0.69365121,  0.06835242,
#          1.30839726, -0.81420695,  2.69531569, -0.9950366 ,  0.59718785,
#         -1.12181904,  0.34289308, -0.49115934, -0.50425475, -0.25828666,
#          0.        ]])

# %%
feature_name_list = [
    'popularity avg',
    'acousticness avg',
    'danceability avg',
    'energy avg',
    'instrumentalness avg',
    'liveness avg',
    'loudness avg',
    'speechiness avg',
    'tempo avg',
    'valence avg',
    'album release year avg',

    'popularity var',
    'acousticness var',
    'danceability var',
    'energy var',
    'instrumentalness var',
    'liveness var',
    'loudness var',
    'speechiness var',
    'tempo var',
    'valence var',
    'album release year var',

    'num_albums',
    'num_artists',
    'num_tracks',
    'collaborative'
]

# %%
len(feature_name_list)
# Out:
# 26

# %%
for _i in range(6):
    print('Center no.', _i)
    for _j in range(26):
        print(feature_name_list[_j], ':', centers[_i][_j], end=' / ')
    print('\n\n')
# Out:
# Center no. 0
# popularity avg : 0.07680885921739002 / acousticness avg : -0.41079258488507003 / danceability avg : 0.21749472572735495 / energy avg : 0.40548636141039474 / instrumentalness avg : -0.17298815991818828 / liveness avg : 0.06772522666768387 / loudness avg : 0.38202405240989873 / speechiness avg : 0.012165388429926519 / tempo avg : 0.1413856009740092 / valence avg : 0.2250760942536259 / album release year avg : 0.09067347976032612 / popularity var : 0.32638245778909764 / acousticness var : -0.11604584469029738 / danceability var : 0.11493756966496613 / energy var : 0.005171902964804737 / instrumentalness var : 0.01445683323051501 / liveness var : 0.18269380401929286 / loudness var : -0.20082661518850414 / speechiness var : 0.19563475383401402 / tempo var : 0.006986186670086137 / valence var : 0.30587786972677244 / album release year var : -0.0030462234323478834 / num_albums : 1.8067322137886 / num_artists : 1.7745722793361822 / num_tracks : 1.666791735469327 / collaborative : 0.0 /
#
#
# Center no. 1
# popularity avg : -0.25082454593377107 / acousticness avg : 0.7607265017177675 / danceability avg : -0.48844613860768477 / energy avg : -0.7423117219028291 / instrumentalness avg : 0.14031291956917014 / liveness avg : -0.6003475520235915 / loudness avg : -0.38516686426707575 / speechiness avg : -0.49185622764845754 / tempo avg : -0.4351514449204669 / valence avg : -0.7122431032143244 / album release year avg : 0.36633048600342466 / popularity var : -0.020579346757558174 / acousticness var : 0.9654681010159122 / danceability var : 0.23133096398251743 / energy var : 0.6378267953126555 / instrumentalness var : 0.4059422311228232 / liveness var : -0.5693869954434209 / loudness var : 0.4039965852741919 / speechiness var : -0.3712594800679939 / tempo var : 0.19450980620142866 / valence var : -0.24201256913161984 / album release year var : -0.1989640028688603 / num_albums : -0.3599305001112692 / num_artists : -0.2887670903130931 / num_tracks : -0.37493805393860685 / collaborative : 0.0 /
#
#
# Center no. 2
# popularity avg : -0.09744390056400183 / acousticness avg : -0.7853911028220107 / danceability avg : 0.0444027984343872 / energy avg : 0.9310668076655684 / instrumentalness avg : -0.17784177743084614 / liveness avg : 0.3499706762369737 / loudness avg : 0.7444855204385867 / speechiness avg : -0.28865979419480714 / tempo avg : 0.5040375930094687 / valence avg : 0.35958722168406915 / album release year avg : 0.25822826176077623 / popularity var : 0.07651074638005095 / acousticness var : -0.8385040344182243 / danceability var : -0.6167206025894874 / energy var : -0.7063073531573815 / instrumentalness var : -0.20453620514124532 / liveness var : 0.26239941274158746 / loudness var : -0.7444622743546152 / speechiness var : -0.34504133186660013 / tempo var : -0.3881024290097486 / valence var : -0.17010653924844799 / album release year var : -0.3221413032659745 / num_albums : -0.34822859652457294 / num_artists : -0.37138962895920885 / num_tracks : -0.33473502157356005 / collaborative : 0.0 /
#
#
# Center no. 3
# popularity avg : -0.21595982398012767 / acousticness avg : 0.38996497901252136 / danceability avg : -0.3519895608975516 / energy avg : -0.17855950659529857 / instrumentalness avg : -0.044427398809441056 / liveness avg : 0.3177805871041138 / loudness avg : -0.5390304477727185 / speechiness avg : -0.5427762473510654 / tempo avg : 0.05762911310577931 / valence avg : 0.8495442169735485 / album release year avg : -1.720923430747505 / popularity var : -0.042601619576167794 / acousticness var : 0.45926167635669296 / danceability var : 0.5850326335657019 / energy var : 0.806132467716718 / instrumentalness var : 0.2533465439421103 / liveness var : 0.5085268406492773 / loudness var : 0.6794125081134998 / speechiness var : -0.4510073593697113 / tempo var : 0.11816748828609758 / valence var : 0.701735914184544 / album release year var : 1.4539498147032268 / num_albums : -0.16991396446967183 / num_artists : -0.15088481496945363 / num_tracks : -0.19880082374841782 / collaborative : 0.0 /
#
#
# Center no. 4
# popularity avg : 0.8024628697178077 / acousticness avg : -0.42382247103131865 / danceability avg : 1.0671791770414103 / energy avg : 0.05371520735204536 / instrumentalness avg : -0.4489358298367124 / liveness avg : 0.15995435106985492 / loudness avg : 0.33387641379726085 / speechiness avg : 1.5173257778750868 / tempo avg : 0.04529689929043225 / valence avg : -0.03054730104102684 / album release year avg : 0.5181973383468897 / popularity var : -0.07420440982977453 / acousticness var : -0.43987750616393745 / danceability var : -0.18147981088414783 / energy var : -0.5513196874631865 / instrumentalness var : -0.692018745405242 / liveness var : 0.0017200572085530963 / loudness var : -0.4441842729490191 / speechiness var : 1.275282379527982 / tempo var : 0.03644825313942519 / valence var : -0.04903630184990313 / album release year var : -0.5367904280662873 / num_albums : -0.20890054189925292 / num_artists : -0.2572827410364501 / num_tracks : -0.12577025490139226 / collaborative : 0.0 /
#
#
# Center no. 5
# popularity avg : -1.4319040953362485 / acousticness avg : 2.4989860851759063 / danceability avg : -2.2224966309796876 / energy avg : -2.46045894021637 / instrumentalness avg : 3.613419103546012 / liveness avg : -0.8039131717333518 / loudness avg : -3.5361952229132534 / speechiness avg : -0.7699156723055943 / tempo avg : -1.5395540611455227 / valence avg : -1.947747325994586 / album release year avg : -0.1576710788885708 / popularity var : -1.094397996788417 / acousticness var : 0.08363876466584064 / danceability var : 0.693651211214842 / energy var : 0.068352416700961 / instrumentalness var : 1.308397263819794 / liveness var : -0.8142069536364693 / loudness var : 2.6953156941447536 / speechiness var : -0.9950365972688181 / tempo var : 0.5971878548356588 / valence var : -1.1218190443411882 / album release year var : 0.34289307550598086 / num_albums : -0.49115933727242167 / num_artists : -0.5042547508628312 / num_tracks : -0.2582866611479416 / collaborative : 0.0 /

# %%
for c_idx in range(len(centers)):
    
    x = centers[c_idx]
    n_groups = len(feature_name_list)
    means_men = x
    
    fig, ax = plt.subplots(figsize=(20, 5))
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] + ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(10)

    index = np.arange(n_groups)
    bar_width = 0.30

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    rects1 = ax.bar(index, means_men, bar_width,
                    alpha=opacity, color='b',
                    error_kw=error_config,
                    label='playlist features')

    ax.set_xlabel(str(c_idx))
    ax.set_ylabel(str(c_idx))
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(feature_name_list, rotation=60)
    ax.legend()
    fig.tight_layout()
#     plt.savefig('inst_vec_img/' + str(g_idx) + genre_txt_list[g_idx].replace('/', '-') + '.png')

# %%
def kmeans_attr(_x, n_c=4):
    _km = KMeans(n_clusters=n_c)
    _km.fit(_x)
    return _km, _km.predict(_x), _km.cluster_centers_

# %%
def get_clustered_title_and_description(_clustered_x, num_cluster=20, pl_Y_title=pl_Y_title, pl_Y_desc=pl_Y_desc):
    clustered_titles = [[] for _ in range(num_cluster)]
    clustered_descriptions = [[] for _ in range(num_cluster)]
    for _idx in range(len(_clustered_x)):
        curr_label = _clustered_x[_idx]
        clustered_titles[curr_label].append(pl_Y_title[_idx])
        clustered_descriptions[curr_label].append(pl_Y_desc[_idx])
    return clustered_titles, clustered_descriptions

# %%
std_pl_X_var = std_pl_X[:, 11:]
std_pl_X_var_km_model, std_pl_X_var_km_y, std_pl_X_var_km_centers = kmeans_attr(std_pl_X_var, 6)
ct_std_pl_X_var, cd_std_pl_X_var = get_clustered_title_and_description(std_pl_X_var_km_y)

# %%
print(np.unique(std_pl_X_var_km_y, return_counts=True))
# Out:
# (array([0, 1, 2, 3, 4, 5], dtype=int32), array([3264, 3205, 4424, 2606, 3053, 2208]))

# %%
len(cd_std_pl_X_var)
# Out:
# 20

# %%
print(std_pl_X_var_km_centers)
# Out:
# [[ 0.2145069   0.32182524  0.27941162  0.53309581 -0.02683851  0.44124214
#    0.23616901 -0.46704344 -0.04774765  0.50877461  0.90967052 -0.26259318
#   -0.24651549 -0.30782119  0.        ]
#  [ 0.25140193 -0.11366766  0.08063503 -0.01666109 -0.0244126   0.18395513
#   -0.14960729  0.1788215   0.02696861  0.21093728 -0.00348225  1.74466052
#    1.66283832  1.65683585  0.        ]
#  [ 0.11295777 -0.32711265 -0.01970292 -0.45999774 -0.56304113 -0.02130138
#   -0.47863035  1.00257274  0.19637172  0.02758312 -0.52061843 -0.26196968
#   -0.27209336 -0.21417896  0.        ]
#  [-0.16896848  0.72212899 -0.1859373   0.34674304  0.22782268 -0.92313719
#    0.48389536 -0.80169781  0.20131433 -1.07923037 -0.21435808 -0.54129121
#   -0.50797021 -0.55016502  0.        ]
#  [-0.12795424 -1.11516749 -1.02271708 -1.05603624 -0.25933489  0.21426294
#   -0.83572242 -0.30224606 -0.83866503 -0.45681586 -0.4667844  -0.47017021
#   -0.4912364  -0.47025218  0.        ]
#  [-0.53141936  1.03386713  1.14309072  1.20832626  1.29183311 -0.08279535
#    1.41066379 -0.2125175   0.5601933   0.79244505  0.60184314 -0.3301582
#   -0.22512705 -0.22100889  0.        ]]

# %%
print(std_pl_X_var_km_centers[0])
print(cd_std_pl_X_var[0])
# Out:
# [ 0.2145069   0.32182524  0.27941162  0.53309581 -0.02683851  0.44124214
#   0.23616901 -0.46704344 -0.04774765  0.50877461  0.90967052 -0.26259318
#  -0.24651549 -0.30782119  0.        ]
# ['What I listen to crusing on my motorcycle', '&lt;Insert catchy description here&gt;', "Denis says, &quot;Listen to Beatles, and you won't regret it!&quot;", 'inspired heavily by Big Little Lies lol', 'I wrote a song for you and it was called yellow', 'You know who you are', 'this is callieween, this is callieween', 'I love you', "he's got a still small voice. you better be quiet.", '#ObnoxiousName', 'Songs for the Revolution', 'Happy, uplifting, turn your bad day around music.', '(to lazy to make more playlists)', 'catchin you in the romantic feels', 'this is actually super gay idk', 'Give a little listen, see the world from my eyes...', 'Just for driving', 'Sunny day playlist. Jump in your convertible and jam', 'Mulholland Drive', 'Grateful Dead and Jerry Garcia side projects', 'to play at max volume with the windows rolled down. hotrod optional.', 'big band/swing, jazz, soul, acoustics, piano, guitar', 'Songs that remind me of myself', 'well not TECHNICALLY', 'All my favorite Bowie songs! He was an incredible artist. Constantly changing his looks and sound, he was able to stay &quot;current&quot; with his legions of fans. Even as an actor, he had a dramatic presence that demanded attention! RIP, we miss you.', 'My playlist to just sit and jam out to. Chill and relaxing, nothing to hard (For me)', '50s 60s &amp; 70s', 'what i have mostly listened to this fall season. revisiting old favorites, falling in love w/ new tracks, finally finding something the smiths fits into + additions from discover weekly. what a lengthy description....', 'Worship/ STRONG faith based music', '*insert sad spongebob face*', 'love songs', 'Summer 2016', 'Processional/Bride/Pronouncement and Exit/First Dance/Father Daughter/End of Dance Party/Exit', 'For those Rogers and Hammerstein vibes', 'mellow moods mellow vibes', 'music of the revolution', 'Collection of some of the catchiest songs around.', "Aimee's top 20", "Isaac's favorite summer jams", 'just a bunch of throwbacks mostly from decades before I was alive', 'A music playlist inspired by the colorful people, places, and experiences that makes Los Angeles the magical city that it is.', 'songs for my sister', 'best time of year', 'Makes you feel good boi :)', "with this playlist it's that time of year all the time", 'The Jams I jam to while at Hope.', "Jamz for when I'm at work", 'effin awesome songs', 'Jams to make you smile', "March...it's more than just about college basketball.", 'pasteles, coquito con un chirirín de nieve', "VOLUME 18 OF SARAH'S JAMS", 'lit bro', "music to listen to w/ friends :')", 'All the music I like in one playlist', 'my dad music lol', 'One of my favorite decades for music....lots of garage rock.', "so, this is my life. and I want you to know that I am both happy and sad and I'm still trying to figure out how that could be.", "upbeat happy tunes when you're feelin' yourself", 'marley, tosh, isaacs, 311', 'in case you need nice things to listen to', 'Relaxing tunes', 'Walkup songs and opposing team trolling music', 'lets gooooooooo', 'my favorite pg songs ;)', 'christmas music... duh', 'i love ur ass forever', 'Including Passenger, James Vincent McMorrow, Vance Joy, Kaleo, and the Lumineers', 'Indie and pop mix', 'in thę making', 'For all the holiday finatics', 'indie rock/britpop', "Mix of tunes from the 70's/80's bands many of which inflenced by the psycadelic movement.", 'Jams my Dad listens to.', '2017', 'No one understands you, except for these songs.', "Music of the 1950's. Got that soul.", 'for calming down', "Songs that are just personally nostalgic. That's it.", "Anything you wouldn't normally tell people you listen to. Can include songs from artists you listened to in highschool that you still listen to occasionally.", 'Happy Birthday Max', "Songs I wouldn't skip. For best results shuffle I added them by artist", 'when matt &amp; i have our bomb ass wedding &amp; everyone is super jealous of how great we are', 'in progress', 'You got any soul in yuh ??', 'fo ...

# %%
print(km_danceability_centers[-6])
print(ct_danceability[-6])
# Out:
# [0.80831269]
# ['hit it', 'lit', 'lit', "it's lit", 'get hype', 'aux', 'hype', '⚡️', 'old skool', '10 10', 'hyphy', "rapper's delight", 'baller', 'title', 'sauce', 'house', 'shake', 'berlin', 'pregame', 'blow', 'heavy rotation', 'rap', 'get crunk', 'funk', 'party playlist', 'dumb lit', 'ratchet', 'school', 'roots', 'party people', 'underground', 'tu', 'booty', 't r a p', 'funk', 'drive by', 'fire', 'bus', 'express yourself', 'ho ho ho', "it's a trap", 'compton', 'loud', 'fire🔥', 'grind', 'ummm', 'loud', 'trashy', '21 savage', "groovin'", '¯\\ ツ ¯', 'the playlist', 'bumping', 'yay area', 'bachata', 'savage mode', 'rn', 'hazy', 'yay area', 'old school rap', 'mosh', 'dirty south', 'booty', 'heat', 'bachata', 'ass', 'beastmode', "it's lit", 'hype', 'skrt', 'old school', 'g-funk', 'lit', 'h y p e', 'tb', 'orishas', 'rap mix', 'party music', 'rap', 'gangsta', 'hoe', 'boi', 'new new', 'slap', 'nwa', 'clouds', 'dank', 'old school', 'fuego', "bumpin'", 'party playlist', 'issa playlist', 'lit songs', 'icy', 'jackson', "90's rap", 'recents', 'old school hip-hop', 'butts', 'yes', 'sweat', 'underground', '99', 'bad', 'trash', 'slaps', 'oldschool', 'litty', 'reggae', 'gang gang', 'icy', 'recent', 'lol', 'legendary', 'four', 'bang', 'lit af', 'clout', 'nee', 'trash', 'music', 'throwback thursday', 'litty', 'chillin', 'old school', '2017', 'throw it back', 'rap mix', 'party bangers', 'h y p e', "summer '16", 'yuh', '28', 'trash', 'esketit', "alex's playlist", 'fire mixtape', 'friyay', '⚡️⚡️⚡️', 'old school hip-hop', "summer '16", 'work it out', 'the sun', 'hypeee', 'bay area', 'stream', 'classic dance', 'hehehe', 'lit', 'rap', 'old skool', 'litty🔥', 'mood', 'skrrr', 'cool beans', 'lituation', "max's playlist", 'car songs', 'atlanta', 'good playlist', 'middle school dance', 'vogue', 'good mood', 'hyphy', 'haus', "it's lit", 'gang gang', 'reggae', 'look at me', 'i like these songs', 'hype', 'dancing', 'werkout', 'west coast classics', 'lit', 'school songs', 'electro swing', 'bouncy', 'selfish', 'dope', 'trash', 'party playlist', 'bops', 'jamz']

# %%
print(ct_std_pl_X_var[0])
# Out:
# ['cruisin', "john's playlist", 'beatles', 'april showers', 'lighthouse', 'songs that remind me of you', 'oct 17', 'grandpa', 'jesus jamz', 'throwbackthursday', 'revolution', "don't worry be happy", 'luna', 'amor', 'for you', 'gaming playlist', 'drive', 'yeah baby', 'june', 'grateful dead', "summer '17", 'sunday', 'indie', 'not rap', 'best of bowie', 'chill out', 'oldies but goodies', 'autumn', 'focus', 'feels', 'xoxo', 'drive', 'special songs', 'showtunes', 'mellow vibes', "60's", 'tasty jams', 'aimee', 'in the summertime', 'tb', 'summer', "megan's playlist", 'christmas', 'feel good', 'christmas', 'hope', 'work jamz', 'best', 'for mom', 'march madness', 'navidad', 'oct17', 'oldies but goodies', 'salon', 'mixtape 1', 'old stuff', "60's", 'lost', "feelin' good", 'reggae', '<3', 'relaxed', 'baseball', '70s', 'yay', 'christmas', 'alli', 'my favorites', 'wedding music', 'for u', 'tis the season', 'the one', 'psychadelic', 'dad jams', 'summer', 'olive', 'classic oldies', 'edgy', 'sail', 'guilty pleasures', "max's playlist", 'absolute favorites', 'best day of my life', 'ssss', 'the king', 'caleb', 'oldies but goodies', 'old school', 'dinner', 'baby', 'indie alt', 'love', '<3', 'doo wop', '10 10', 'bittersweet', 'just chill', 'indie', 'classic rock', 'nostalgia', 'jams', 'my favorites', 'the good old days', 'mexico', 'queens', 'for jack', 'easy going', 'february', 'yoga playlist', 'young blood', 'chill out', 'queens', 'old school hits', 'post-punk', 'okay', 'harry', 'classic', 'new stuff', 'subway', 'life', 'baby', 'good songs', 'dad jams', 'about you', 'zzz', 'old', 'cool', 'hayley', 'old times', 'nugget', 'love songs', '⚜️', 'fun times', 'right now', 'harvest moon', 'worship', 'kristen', 'crispy', 'sick jams', 'classic', 'june', 'country', 'almost famous', "road trippin'", 'berlin', 'caroline', 'kh', 'classic rock', 'weekend', 'naps', 'chill', 'the playlist', 'favorite songs', 'vintage', 'uplift', 'oldie goldies', 'april', 'commute', 'vibes', 'roots', 'good feels', 'cocktail hour', 'get up and dance', 'ummm', 'margaritaville', 'pump it up', 'get ready', '<3', 'all time favorites', 'good morning', 'espanol', 'travelling', 'sister', 'mixtape', 'cali', 'jump', 'soft rock', "rollin'", 'summer 2017', 'amanda', 'country', 'finals', 'jams', 'jukebox', 'legendary', 'traffic jams', "october '17", 'earth', 'maddy', 'calm down', 'country', 'vibin', 'ya like jazz?', 'worship', 'work in progress', 'oldies', 'chill', 'feels', 'nye', 'happy days', 'jazz', 'good vibes', 'girl power', 'songs that make me think of you', 'low', 'sixteen', 'mixtape 1', 'litty titty', 'brooklyn', 'october 2017', 'snoop', 'older', 'mixed emotions', 'love sucks', 'roots', 'beatles', 'soul funk', 'on the road again', 'all time best', 'roadtrip jams', 'i miss you', 'soul', 'nice', '3 0', 'happy days', 'the best', '1980', 'happy times', 'mom', 'mixtape 1', 'drive', 'disney playlist', 'high on life', "relaxin'", 'colors', 'oldies but goodies', 'timeless classics', 'christmas 2016', 'witchcraft', 'spaced out', 'rach', 'mood', 'cute', 'amor', 'i feel good', 'noviembre', 'demons', 'morning', 'angel', 'christmas', 'dubai', 'work', 'this must be the place', 'sabbath', 'twenty one', 'swanky', 'awesome mix vol 2', 'chill beats', 'oldies', 'random stuff', 'pumped', 'hannah', 'old new', 'oldies but goldies', 'cookout', 'nostalgia', 'halloween 2016', 'done', 'nice', 'trippin', 'boy band', 'idk yet', 'nostalgia', 'pride', 'old gold', 'feel good tunes', 'nicole', 'pch', 'breathe', "june '17", 'sing it', 'best', 'my favorite songs', 'get schwifty', 'current favorites', 'unknown', 'chris cornell', 'praise', 'christmassss', 'throwback', 'chill', 'classics', 'michael jackson', 'rocks', 'car tunes', 'seventies', 'pumped up', 'ya like jazz?', 'love of my life', 'weekend', 'yoga flow', 'for ashley', 'open road', 'silly love songs', 'grad party', 'meme', 'play me', 'olivia', 'aesthetics', 'motown', 'spring 2017', 'songs to dance to', 'tranquil', 'halloween playlist', 'current favorites', 'recent ...

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_pl_X_var = tsne.fit_transform(std_pl_X_var)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 18760 samples in 0.012s...
# [t-SNE] Computed neighbors for 18760 samples in 8.016s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 18760
# [t-SNE] Computed conditional probabilities for sample 2000 / 18760
# [t-SNE] Computed conditional probabilities for sample 3000 / 18760
# [t-SNE] Computed conditional probabilities for sample 4000 / 18760
# [t-SNE] Computed conditional probabilities for sample 5000 / 18760
# [t-SNE] Computed conditional probabilities for sample 6000 / 18760
# [t-SNE] Computed conditional probabilities for sample 7000 / 18760
# [t-SNE] Computed conditional probabilities for sample 8000 / 18760
# [t-SNE] Computed conditional probabilities for sample 9000 / 18760
# [t-SNE] Computed conditional probabilities for sample 10000 / 18760
# [t-SNE] Computed conditional probabilities for sample 11000 / 18760
# [t-SNE] Computed conditional probabilities for sample 12000 / 18760
# [t-SNE] Computed conditional probabilities for sample 13000 / 18760
# [t-SNE] Computed conditional probabilities for sample 14000 / 18760
# [t-SNE] Computed conditional probabilities for sample 15000 / 18760
# [t-SNE] Computed conditional probabilities for sample 16000 / 18760
# [t-SNE] Computed conditional probabilities for sample 17000 / 18760
# [t-SNE] Computed conditional probabilities for sample 18000 / 18760
# [t-SNE] Computed conditional probabilities for sample 18760 / 18760
# [t-SNE] Mean sigma: 0.763813
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.471909
# [t-SNE] Error after 300 iterations: 3.979688

# %%
plt.figure(figsize=(16,10))
plt.scatter(tsne_pl_X_var[:, 0], tsne_pl_X_var[:, 1], c=std_pl_X_var_km_y, s=1, cmap='viridis')

# %%
# std_pl_X_var_km_model, std_pl_X_var_km_y, std_pl_X_var_km_centers

# %%
for c_idx in range(len(std_pl_X_var_km_centers)):
    
    x = std_pl_X_var_km_centers[c_idx]
    n_groups = len(feature_name_list[11:])
#     means_men = x
    
    fig, ax = plt.subplots(figsize=(20, 5))
    for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] + ax.get_xticklabels() + ax.get_yticklabels()):
        item.set_fontsize(10)

    index = np.arange(n_groups)
    bar_width = 0.30

    opacity = 0.4
    error_config = {'ecolor': '0.3'}

    rects1 = ax.bar(index, x, bar_width,
                    alpha=opacity, color='b',
                    error_kw=error_config,
                    label='playlist features')

    ax.set_xlabel(str(c_idx))
    ax.set_ylabel(str(c_idx))
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(feature_name_list[11:], rotation=60)
    ax.legend()
    fig.tight_layout()
#     plt.savefig('inst_vec_img/' + str(g_idx) + genre_txt_list[g_idx].replace('/', '-') + '.png')

# %%
# from datetime import datetime
# import logging
# import pandas as pd
# from pyspark.sql import SparkSession
# from pyspark.sql.window import Window
# from pyspark.sql import HiveContext
# from pyspark.sql import SQLContext
# from pyspark.sql.functions import to_date, col, count, row_number, \
#                                   desc, explode, least, size, coalesce, collect_list, collect_set

# spark = SparkSession.builder.enableHiveSupport().config(
#             "spark.hadoop.avro.mapred.ignore.inputs.without.extension", "false").getOrCreate()
# sc = spark.sparkContext

# sqlContext = SQLContext(sc)
# hiveCtx = HiveContext(sc)

# discogs_tags = sqlContext.read.format("com.databricks.spark.avro").load(
#             "/research/enki/discogs/album_discogs_parsed")
# discogs_tags = discogs_tags.filter("discogs_tag_type = 'genre' or discogs_tag_type='style'").groupBy(
#     "discogs_release_id").agg(collect_set("discogs_tag_name").alias("discogs_genres"))

# enki_discogs = hiveCtx.sql("select dz_id, discogs_id from research.enki_album_deezer_discogs")
# discogs_tags_enki = discogs_tags.join(
#     enki_discogs, discogs_tags.discogs_release_id == enki_discogs.discogs_id).select(
#     "discogs_id", "discogs_genres", "dz_id").withColumnRenamed("dz_id", "album_id")
# import pandas as pd
# msd_to_deezer = pd.read_csv("workspace/enki_track_msd.csv")
# msd_to_deezer
# msd_to_deezer = pd.read_csv("workspace/enki_track_msd.csv", sep="\t")
# msd_to_deezer
# dz_msd_track_df = sqlContext.createDataFrame(sc.parallelize(list(zip(msd_to_deezer["dz_id"], msd_to_deezer["msd_id"]))), ["song_id", "msd_id"])
# songs_table = hiveCtx.sql(
#             "select song_id, album_id from dwh.song")
# msd_track_album_id = dz_msd_track_df.join(songs_table, "song_id")


# def as_dwh_token(d):
#     return d.strftime("%Y%m%d")

# def as_reco_token(d):
#     return d.strftime("%Y-%m-%d")

# def today_table_token():
#     return as_dwh_token(datetime.now())

# album_table = hiveCtx.read.orc(
#         "/hive/dwh.db/album/{}".format(today_table_token())).select(
#             "album_id", "product_album_id")
# discogs_tags_enki = discogs_tags_enki.join(album_table, "album_id")
# msd_track_album_id = msd_track_album_id.join(album_table, "album_id")
# msd_dsg_tags = msd_track_album_id.join(discogs_tags_enki, "product_album_id").cache()

# msd_dsg_tags_df = msd_dsg_tags.select("song.album_id", "discogs_id", "discogs_genres", "song_id", "msd_id").toPandas()
# msd_dsg_tags_df.to_csv("workspace/discogs_tags_msd.csv", index=False)
